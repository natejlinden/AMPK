# %% [markdown]
# # Mass-action kinetics, double binding
#
# This notebook explores several models of AMPK activation.
#
# Nathaniel Linden (UCSD MAE) - Feb  2023

# %%
import sunode
import pymc as pm
import matplotlib.pyplot as plt
import numpy as np
import sympy as sym
from sympy import init_printing
init_printing()

import sys
sys.path.insert(0, '../odes')
import ampk_MA_double_mech as model1
from get_left_nullspace_vecs_invariants import get_left_nullspace_vecs_invariants as left_ns
from get_right_nullspace_vecs import get_right_nullspace_vecs as right_ns
# %matplotlib inline

# %% [markdown]
# ## Double binding, mass action kinetics model
# We will start with the relevant initial conditions and parameters from Coccimiglio et al.
# Parameter values are taken from Sup Table D col "pre-calibration value," thus they are from Xiao et al. Nature 2011.
# Initial conditions are taken from Sup Table
#
# Parameters not included in that model are assigned arbitrarily.
#
# **Note that this simulation just tests the machinery of the model and simulation!**

# %%
# First we want to check that the model obeys proper conservation of mass
# use our function for this
rhs, sym_fluxes = model1.ampk_MA_double_mech_RHS_sympyFluxVars()
stoich, left_ns_vecs, invars = left_ns(rhs, sym_fluxes)
stoich, right_ns_vecs = right_ns(rhs, sym_fluxes)
for idx, invariant in zip(range(len(invars)), invars):
    print('The {} invariant is:'.format(idx))
    sym.pprint(invariant, use_unicode=True)
    print('\n')
# Out:
# The 0 invariant is:
# [CaMKK + CaMKKADPADPAMPK + CaMKKADPAMPK + CaMKKADPATPAMPK + CaMKKAMPADPAMPK +
# CaMKKAMPAMPAMPK + CaMKKAMPAMPK + CaMKKAMPATPAMPK + CaMKKAMPK + CaMKKATPAMPK +
# CaMKKATPATPAMPK]
#
#
# The 1 invariant is:
# [LKB₁ + LKB1ADPADPAMPK + LKB1ADPAMPK + LKB1AMPADPAMPK + LKB1AMPAMPAMPK + LKB1A
# MPAMPK]
#
#
# The 2 invariant is:
# [PP + PPADPATPpAMPK + PPAMPATPpAMPK + PPATPATPpAMPK + PPATPpAMPK + PPpAMPK]
#
#
# The 3 invariant is:
# [-ADP + ADPAMPK + ADPpAMPK - AMP + AMPAMPK + 2⋅AMPK + AMPKARAMPpAMPK + AMPpAMP
# K - ATP + ATPAMPK + ATPpAMPK + CaMKKADPAMPK + CaMKKAMPAMPK + 2⋅CaMKKAMPK + CaM
# KKATPAMPK + LKB1ADPAMPK + LKB1AMPAMPK + PPATPpAMPK + 2⋅PPpAMPK + 2⋅pAMPK]
#
#
# The 4 invariant is:
# [ADP + ADPADPAMPK + ADPADPpAMPK + ADPATPAMPK + ADPATPpAMPK + AMP + AMPADPAMPK
# + AMPADPpAMPK + AMPAMPAMPK + AMPAMPpAMPK + AMPATPAMPK + AMPATPpAMPK - AMPK + A
# MPKARAMPADPpAMPK + AMPKARAMPAMPpAMPK + ATP + ATPATPAMPK + ATPATPpAMPK - CaMKK
# - CaMKKADPAMPK - CaMKKAMPAMPK - 2⋅CaMKKAMPK - CaMKKATPAMPK - LKB₁ - LKB1ADPAMP
# K - LKB1AMPAMPK - PP - PPATPpAMPK - 2⋅PPpAMPK - pAMPK]
#
#
# The 5 invariant is:
# [ADPADPAMPK + ADPADPpAMPK + ADPAMPK + ADPATPAMPK + ADPATPpAMPK + ADPpAMPK + AM
# PADPAMPK + AMPADPpAMPK + AMPAMPAMPK + AMPAMPK + AMPAMPpAMPK + AMPATPAMPK + AMP
# ATPpAMPK + AMPK - AMPKAR + AMPpAMPK + ATPAMPK + ATPATPAMPK + ATPATPpAMPK + ATP
# pAMPK - CaMKK - LKB₁ - PP + PP₁ + pAMPK - pAMPKAR]
#
#
# The 6 invariant is:
# [-ADPADPAMPK - ADPADPpAMPK - ADPAMPK - ADPATPAMPK - ADPATPpAMPK - ADPpAMPK - A
# MPADPAMPK - AMPADPpAMPK - AMPAMPAMPK - AMPAMPK - AMPAMPpAMPK - AMPATPAMPK - AM
# PATPpAMPK - AMPK + AMPKAR - AMPpAMPK - ATPAMPK - ATPATPAMPK - ATPATPpAMPK - AT
# PpAMPK + CaMKK + LKB₁ + PP + PP1pAMPKAR - pAMPK + pAMPKAR]

# %% [markdown]
# Invariants 0, 1, 2 make sense as they are conservation of CaMKK, LKB1, and PP, respectively. However, 3,4,5 are not particularly meaningful. Thus, we look at linear combinations of these.

# %%
# 0+1+2+3+4
print('Invariant {i} + {j} + {k} + {l} + {m}:'.format(i=0, j=1, k=2, l=3, m=4))
ampk_invar = invars[0]+invars[1]+invars[2]+invars[3]+invars[4]
sym.pprint(ampk_invar, use_unicode=True)
print('\n')

# 5 + 6
print('Invariant {i} + {j}:'.format(i=5, j=6))
sym.pprint(invars[5]+invars[6], use_unicode=True)
print('\n')

# 5 - 6 + ampk_invar
print('Invariant {i} + {j} + {k}:'.format(i=3, j=4, k=6))
sym.pprint(invars[3]+invars[4]+invars[6], use_unicode=True)
print('\n')
# Out:
# Invariant 0 + 1 + 2 + 3 + 4:
# [ADPADPAMPK + ADPADPpAMPK + ADPAMPK + ADPATPAMPK + ADPATPpAMPK + ADPpAMPK + AM
# PADPAMPK + AMPADPpAMPK + AMPAMPAMPK + AMPAMPK + AMPAMPpAMPK + AMPATPAMPK + AMP
# ATPpAMPK + AMPK + AMPKARAMPADPpAMPK + AMPKARAMPAMPpAMPK + AMPKARAMPpAMPK + AMP
# pAMPK + ATPAMPK + ATPATPAMPK + ATPATPpAMPK + ATPpAMPK + CaMKKADPADPAMPK + CaMK
# KADPAMPK + CaMKKADPATPAMPK + CaMKKAMPADPAMPK + CaMKKAMPAMPAMPK + CaMKKAMPAMPK
# + CaMKKAMPATPAMPK + CaMKKAMPK + CaMKKATPAMPK + CaMKKATPATPAMPK + LKB1ADPADPAMP
# K + LKB1ADPAMPK + LKB1AMPADPAMPK + LKB1AMPAMPAMPK + LKB1AMPAMPK + PPADPATPpAMP
# K + PPAMPATPpAMPK + PPATPATPpAMPK + PPATPpAMPK + PPpAMPK + pAMPK]
#
#
# Invariant 5 + 6:
# [PP₁ + PP1pAMPKAR]
#
#
# Invariant 3 + 4 + 6:
# [AMPKAR + AMPKARAMPADPpAMPK + AMPKARAMPAMPpAMPK + AMPKARAMPpAMPK + PP1pAMPKAR
# + pAMPKAR]

# %%
# load the necessary dictionaries
params = model1.ampk_MA_double_mech_get_params()
states = model1.ampk_MA_double_mech_get_states()
nparams = len(params)
nstates = len(states)

# create sunode problem
problem = sunode.SympyProblem(
    params=params,
    states=states,
    rhs_sympy=model1.ampk_MA_double_mech_RHS,
    # specify variables to take gradients wrt
    derivative_params=(),
)

# set up solver
solver = sunode.solver.Solver(problem, solver='BDF')

# Initial conditions
y0 = np.zeros((), dtype=problem.state_dtype)
# free adenine nucleotides
y0['AMP'] = 2e-5   # 'AMP' mM
y0['ATP'] = 1.3e-1 # 'ADP mM
y0['ADP'] = 8.2   # 'ATP mM
# # free AMPK
y0['AMPK'] = 6   # 'AMPK mM
y0['pAMPK'] = 0   # 'pAMPK mM
# # single AXP-AMPK complexes
y0['AMP_AMPK'] = 0  # 'AMP_AMPK mM
y0['ADP_AMPK'] = 0   # 'ADP_AMPK mM
y0['ATP_AMPK'] = 0   # 'ATP_AMPK mM
# # single AXP-pAMPK complexes
y0['AMP_pAMPK'] = 0   # 'AMP_pAMPK mM
y0['ADP_pAMPK'] = 0   # 'ADP_pAMPK mM
y0['ATP_pAMPK'] = 0   # 'ATP_pAMPK mM
# # double AXP-AMPK complexes
y0['AMP_AMP_AMPK'] = 0   # 'AMP_AMP_AMPK mM
y0['AMP_ADP_AMPK'] = 0   # 'AMP_ADP_AMPK mM
y0['AMP_ATP_AMPK'] = 0   # 'AMP_ATP_AMPK mM
y0['ADP_ADP_AMPK'] = 0   # 'ADP_ADP_AMPK mM
y0['ADP_ATP_AMPK'] = 0   # 'ADP_ATP_AMPK mM
y0['ATP_ATP_AMPK'] = 0   # 'ATP_ATP_AMPK mM
# # double AXP-pAMPK complexes
y0['AMP_AMP_pAMPK'] = 0   # 'AMP_AMP_pAMPK mM
y0['AMP_ADP_pAMPK'] = 0   # 'AMP_ADP_pAMPK mM
y0['AMP_ATP_pAMPK'] = 0   # 'AMP_ATP_pAMPK mM
y0['ADP_ADP_pAMPK'] = 0   # 'ADP_ADP_pAMPK mM
y0['ADP_ATP_pAMPK'] = 0   # 'ADP_ATP_pAMPK mM
y0['ATP_ATP_pAMPK'] = 0   # 'ATP_ATP_pAMPK mM
# # CaMKK complexes
y0['CaMKK'] = 10.0   # 'CaMKK_AMPK mM
y0['CaMKK_AMPK'] = 0   # 'CaMKK_AMPK mM
y0['CaMKK_AMP_AMPK'] = 0   # 'CaMKK_AMP_AMPK mM
y0['CaMKK_ADP_AMPK'] = 0   # 'CaMKK_ADP_AMPK mM
y0['CaMKK_ATP_AMPK'] = 0   # 'CaMKK_ATP_AMPK mM
y0['CaMKK_AMP_AMP_AMPK'] = 0   # 'CaMKK_AMP_AMP_AMPK mM
y0['CaMKK_AMP_ADP_AMPK'] = 0   # 'CaMKK_AMP_ADP_AMPK mM
y0['CaMKK_AMP_ATP_AMPK'] = 0   # 'CaMKK_AMP_ATP_AMPK mM
y0['CaMKK_ADP_ADP_AMPK'] = 0   # 'CaMKK_ADP_ADP_AMPK mM
y0['CaMKK_ADP_ATP_AMPK'] = 0   # 'CaMKK_ADP_ATP_AMPK mM
y0['CaMKK_ATP_ATP_AMPK'] = 0   # 'CaMKK_ATP_ATP_AMPK mM
# # LKB1 complexes
y0['LKB1'] = 10.0   # 'CaMKK_AMPK mM
y0['LKB1_AMP_AMPK'] = 0   # 'LKB1_AMP_AMPK mM
y0['LKB1_ADP_AMPK'] = 0   # 'LKB1_ADP_AMPK mM
y0['LKB1_AMP_AMP_AMPK'] = 0   # 'LKB1_AMP_AMP_AMPK mM
y0['LKB1_AMP_ADP_AMPK'] = 0   # 'LKB1_AMP_ADP_AMPK mM
y0['LKB1_ADP_ADP_AMPK'] = 0   # 'LKB1_ADP_ADP_AMPK mM
# # AMPK phosphatase complexes
y0['PP'] = 5.0   # 'CaMKK_AMPK mM
y0['PP_pAMPK'] = 0   # 'PP_pAMPK mM
y0['PP_ATP_pAMPK'] = 0   # 'PP_ATP_pAMPK mM
y0['PP_AMP_ATP_pAMPK'] = 0   # 'PP_AMP_ATP_pAMPK mM
y0['PP_ADP_ATP_pAMPK'] = 0   # 'PP_ADP_ATP_pAMPK mM
y0['PP_ATP_ATP_pAMPK'] = 0   # 'PP_ATP_ATP_pAMPK mM
# # free AMPKAR
y0['AMPKAR'] = 3.0   # 'AMPKAR mM
y0['pAMPKAR'] = 0   # pAMPKAR
# # AMPKAR-pAMPK complexes
y0['AMPKAR_AMP_pAMPK'] = 0   # 'AMPKAR_AMP_pAMPK' mM
y0['AMPKAR_AMP_AMP_pAMPK'] = 0   # 'AMPKAR_AMP_AMP_pAMPK mM
y0['AMPKAR_AMP_ADP_pAMPK'] = 0   # 'AMPKAR_AMP_ADP_pAMPK mM
# # AMPKAR phosphatase complexes
y0['PP1'] = 5.0   # 'CaMKK_AMPK mM
y0['PP1_pAMPKAR'] = 0   # 'PP1_pAMPKAR mM

 # evaluate the solution at these times
tvals = np.linspace(0, 300, 500)

 # set the parameters
 # TODO: MORE RESEARCH ON THE PARAMETERS!
solver.set_params_dict({
    'kOnAMP': 1, # 1/(mM s) - from Coccimiglio 
    'kOffAMP': 2.5e-3, # 1/s - from Coccimiglio 
    'kOnADP': 1 , # 1/(mM s) - from Coccimiglio
    'kOffADP': 1.5e-3, # 1/s - from Coccimiglio
    'kOnATP': 1, # 1/(mM s) - from Coccimiglio 
    'kOffATP': 1.8e-2, # 1/s - from Coccimiglio
    'kOnCaMKK': 1, # TODO - random value!
    'kOffCaMKK': 1e-2, # TODO - random value!
    'kPhosCaMKK': 6.7e-2, # from Coccimiglio, but incorrect parameters 
    'kOnLKB1': 1, # TODO - random value!
    'kOffLKB1': 1e-2, # TODO - random value!
    'kPhosLKB1': 6.7e-2, # from Coccimiglio, but incorrect parameters 
    'kOnPP': 1, # TODO - random value! 
    'kOffPP': 1e-2, # TODO - random value! 
    'kDephosPP': 1.1e-2, # from Coccimiglio, but incorrect parameters 
    'kOnAMPK': 1, # TODO - random value!
    'kOffAMPK': 1e-2, # TODO - random value!
    'kPhosAMPK': 5e-1, # TODO - random value!
    'kOnPP1': 1, # TODO - random value!
    'kOffPP1': 1e-2, # TODO - random value!
    'kDephosPP1': 5e-3, # TODO - random value!
    'kGly': 0.02, # TODO - random value!
    'kHydro':0.05, # TODO - random value!
    'kForAK':4e-6, # TODO - random value!
    'kRevAK':1e-7, # TODO - random value!
    'VmaxOxPhos':0.5 , # mM/s from Coccimiglio,
    'Kadp': 5.8e-2, # mM from Coccimiglio,
    'n': 2.568, # unitless from Coccimiglio,
})

sens0 = np.zeros((nparams, nstates))
yout = solver.make_output_buffers(tvals)
solver.solve(t0=0, tvals=tvals, y0=y0, y_out=yout, sens0=sens0)

# %%
# Metabolism plots
fig0, ax0 = plt.subplots(1,3, figsize=(16,4))
# AMP
# plot [AMP] with thicker line
ax0[0].plot(tvals, yout.view(problem.state_dtype)['AMP'], linewidth=2.5)
AMPtot = yout.view(problem.state_dtype)['AMP']
# everything else
states_to_plot = ['AMP_AMPK', 'AMP_AMP_AMPK', 'AMP_ADP_AMPK', 'AMP_ATP_AMPK', 
                  'AMP_pAMPK', 'AMP_AMP_pAMPK', 'AMP_ADP_pAMPK', 'AMP_ATP_pAMPK']
for state in states_to_plot:
    ax0[0].plot(tvals, yout.view(problem.state_dtype)[state])
    AMPtot += yout.view(problem.state_dtype)[state]
# all AMP-x complexes
ax0[0].plot(tvals, AMPtot, 'k--')
# formatting
ax0[0].set_yscale('log')
ax0[0].set_ylabel('log species concentration')
ax0[0].set_xlabel('time (s)')
ax0[0].set_title('AMP')
# ADP
# plot [ADP] with thicker line
ax0[1].plot(tvals, yout.view(problem.state_dtype)['ADP'], linewidth=2.5)
ADPtot = yout.view(problem.state_dtype)['ADP']
# everything else
states_to_plot = ['ADP_AMPK', 'AMP_ADP_AMPK', 'ADP_ADP_AMPK', 'ADP_ATP_AMPK', 
                  'ADP_pAMPK', 'AMP_ADP_pAMPK', 'ADP_ADP_pAMPK', 'ADP_ATP_pAMPK']
for state in states_to_plot:
    ax0[1].plot(tvals, yout.view(problem.state_dtype)[state])
    ADPtot += yout.view(problem.state_dtype)[state]
# all ADP-x complexes
ax0[1].plot(tvals, ADPtot, 'k--')
# formatting
ax0[1].set_yscale('log')
ax0[1].set_xlabel('time (s)')
ax0[1].set_title('ADP')
# ATP
# plot [ADP] with thicker line
ax0[2].plot(tvals, yout.view(problem.state_dtype)['ATP'], linewidth=2.5)
ATPtot = yout.view(problem.state_dtype)['ATP']
# everything else
states_to_plot = ['ATP_AMPK', 'AMP_ATP_AMPK', 'ADP_ATP_AMPK', 'ATP_ATP_AMPK', 
                  'ATP_pAMPK', 'AMP_ATP_pAMPK', 'ADP_ATP_pAMPK', 'ATP_ATP_pAMPK']
for state in states_to_plot:
    ax0[2].plot(tvals, yout.view(problem.state_dtype)[state])
    ATPtot += yout.view(problem.state_dtype)[state]
# all ATP-x complexes
ax0[2].plot(tvals, ATPtot, 'k--')
# formatting
ax0[2].set_yscale('log')
ax0[2].set_xlabel('time (s)')
ax0[2].set_title('ATP')

fig1, ax1 = plt.subplots(1,1, figsize=(4,4))
AMP_ATP_ratio = yout.view(problem.state_dtype)['AMP'] / yout.view(problem.state_dtype)['ATP']
ADP_ATP_ratio = yout.view(problem.state_dtype)['ADP'] / yout.view(problem.state_dtype)['ATP']
ax1.plot(tvals, AMP_ATP_ratio, 'b', linewidth=2)
ax1.plot(tvals, ADP_ATP_ratio, 'k', linewidth=2)
ax1.set_yscale('log')
ax1.set_ylabel('log AXP:ATP ratio')
ax1.set_xlabel('time (s)')
ax1.legend(('AMP:ATP', 'ADP:ATP'))
ax1.set_title('Adenine nucleotide ratios')
# Out:
# Text(0.5, 1.0, 'Adenine nucleotide ratios')

# %%
# Conserved quantities
# CaMKK
states_to_plot = ['CaMKK', 'CaMKK_AMPK', 'CaMKK_AMP_AMPK', 'CaMKK_ADP_AMPK', 
                  'CaMKK_ATP_AMPK', 'CaMKK_AMP_AMP_AMPK', 'CaMKK_AMP_ADP_AMPK',
                  'CaMKK_AMP_ATP_AMPK', 'CaMKK_ADP_ADP_AMPK','CaMKK_ADP_ATP_AMPK',
                  'CaMKK_ATP_ATP_AMPK']
fig0, ax0 = plt.subplots(1,1, figsize=(4,4))
CaMKKtot = np.zeros(yout.view(problem.state_dtype)['CaMKK'].shape)
for state in states_to_plot:
    CaMKKtot += yout.view(problem.state_dtype)[state]
    ax0.plot(tvals, yout.view(problem.state_dtype)[state])
ax0.plot(tvals, CaMKKtot, 'k--', linewidth=2)
ax0.set_yscale('log')
ax0.set_ylabel('log species concentration')
ax0.set_xlabel('time (s)')
ax0.set_title('CaMKK')

# LKB1
states_to_plot = ['LKB1', 'LKB1_AMP_AMPK', 'LKB1_ADP_AMPK', 'LKB1_AMP_AMP_AMPK',
                   'LKB1_AMP_ADP_AMPK', 'LKB1_ADP_ADP_AMPK']
fig1, ax1 = plt.subplots(1,1, figsize=(4,4))
LKB1tot = np.zeros(yout.view(problem.state_dtype)['LKB1'].shape)
for state in states_to_plot:
    LKB1tot += yout.view(problem.state_dtype)[state]
    ax1.plot(tvals, yout.view(problem.state_dtype)[state])
ax1.plot(tvals, LKB1tot, 'k--', linewidth=2)
ax1.set_yscale('log')
ax1.set_ylabel('log species concentration')
ax1.set_xlabel('time (s)')
ax1.set_title('LKB1')

# PP
states_to_plot = ['PP', 'PP_pAMPK', 'PP_ATP_pAMPK', 'PP_AMP_ATP_pAMPK',
                   'PP_ADP_ATP_pAMPK', 'PP_ATP_ATP_pAMPK']
fig2, ax2 = plt.subplots(1,1, figsize=(4,4))
PPtot = np.zeros(yout.view(problem.state_dtype)['PP'].shape)
for state in states_to_plot:
    PPtot += yout.view(problem.state_dtype)[state]
    ax2.plot(tvals, yout.view(problem.state_dtype)[state])
ax2.plot(tvals, PPtot, 'k--', linewidth=2)
ax2.set_yscale('log')
ax2.set_ylabel('log species concentration')
ax2.set_xlabel('time (s)')
ax2.set_title('PP (pAMPK phosphatase)')

# PP1
states_to_plot = ['PP1','PP1_pAMPKAR']
fig3, ax3 = plt.subplots(1,1, figsize=(4,4))
PP1tot = np.zeros(yout.view(problem.state_dtype)['PP1'].shape)
for state in states_to_plot:
    PP1tot += yout.view(problem.state_dtype)[state]
    ax3.plot(tvals, yout.view(problem.state_dtype)[state])
ax3.plot(tvals, PP1tot, 'k--', linewidth=2)
ax3.set_yscale('log')
ax3.set_ylabel('log species concentration')
ax3.set_xlabel('time (s)')
ax3.set_title('PP1 (pAMPKAR phosphatase)')

# AMPKAR
states_to_plot = ['AMPKAR', 'pAMPKAR', 'PP1_pAMPKAR', 'AMPKAR_AMP_AMP_pAMPK', 
                  'AMPKAR_AMP_pAMPK', 'AMPKAR_AMP_ADP_pAMPK']
fig4, ax4 = plt.subplots(1,1, figsize=(4,4))
AMPKARtot = np.zeros(yout.view(problem.state_dtype)['AMPKAR'].shape)
for state in states_to_plot:
    AMPKARtot += yout.view(problem.state_dtype)[state]
    ax4.plot(tvals, yout.view(problem.state_dtype)[state])
ax4.plot(tvals, AMPKARtot, 'k--', linewidth=2)
ax4.set_yscale('log')
ax4.set_ylabel('log species concentration')
ax4.set_xlabel('time (s)')
ax4.set_title('AMPKAR')

# AMPK
states_to_plot = ['AMPK', 'pAMPK', # uncomplexed
                  'AMP_AMPK', 'ADP_AMPK', 'ATP_AMPK', # single complex
                  'AMP_pAMPK', 'ADP_pAMPK', 'ATP_pAMPK',
                  'AMP_AMP_AMPK', 'AMP_ADP_AMPK', 'AMP_ATP_AMPK', 'ADP_ADP_AMPK', # double complexes
                  'ADP_ATP_AMPK', 'ATP_ATP_AMPK', 'AMP_AMP_pAMPK',
                  'AMP_ADP_pAMPK', 'AMP_ATP_pAMPK', 'ADP_ADP_pAMPK',
                  'ADP_ATP_pAMPK', 'ATP_ATP_pAMPK',
                  'CaMKK_AMPK', 'CaMKK_AMP_AMPK', 'CaMKK_ADP_AMPK', # CaMKK complexes
                  'CaMKK_ATP_AMPK', 'CaMKK_AMP_AMP_AMPK', 'CaMKK_AMP_ADP_AMPK',
                  'CaMKK_AMP_ATP_AMPK', 'CaMKK_ADP_ADP_AMPK','CaMKK_ADP_ATP_AMPK',
                  'CaMKK_ATP_ATP_AMPK',
                  'LKB1_AMP_AMPK', 'LKB1_ADP_AMPK', 'LKB1_AMP_AMP_AMPK', # LKB1 complexes
                  'LKB1_AMP_ADP_AMPK', 'LKB1_ADP_ADP_AMPK',
                  'AMPKAR_AMP_AMP_pAMPK','AMPKAR_AMP_pAMPK', 'AMPKAR_AMP_ADP_pAMPK' # AMPKAR complexes
                  ]

states_to_plot1 = ['AMPK','pAMPK','AMP_AMPK','ADP_AMPK','ATP_AMPK','AMP_pAMPK','ADP_pAMPK','ATP_pAMPK','AMP_AMP_AMPK',
'AMP_ADP_AMPK','AMP_ATP_AMPK','ADP_ADP_AMPK','ADP_ATP_AMPK','ATP_ATP_AMPK','AMP_AMP_pAMPK','AMP_ADP_pAMPK',
'AMP_ATP_pAMPK','ADP_ADP_pAMPK','ADP_ATP_pAMPK','ATP_ATP_pAMPK','CaMKK_AMPK',
'CaMKK_AMP_AMPK','CaMKK_ADP_AMPK','CaMKK_ATP_AMPK','CaMKK_AMP_AMP_AMPK',
'CaMKK_AMP_ADP_AMPK','CaMKK_AMP_ATP_AMPK','CaMKK_ADP_ADP_AMPK','CaMKK_ADP_ATP_AMPK','CaMKK_ATP_ATP_AMPK',
'LKB1_AMP_AMPK','LKB1_ADP_AMPK','LKB1_AMP_AMP_AMPK','LKB1_AMP_ADP_AMPK',
'LKB1_ADP_ADP_AMPK','PP_pAMPK','PP_ATP_pAMPK','PP_AMP_ATP_pAMPK','PP_ADP_ATP_pAMPK',
'PP_ATP_ATP_pAMPK','AMPKAR_AMP_pAMPK','AMPKAR_AMP_AMP_pAMPK','AMPKAR_AMP_ADP_pAMPK']
fig5, ax5 = plt.subplots(1,1, figsize=(4,4))
AMPKtot = np.zeros(yout.view(problem.state_dtype)['AMPK'].shape)
for state in states_to_plot1:
    AMPKtot += yout.view(problem.state_dtype)[state]
    ax5.plot(tvals, yout.view(problem.state_dtype)[state])
ax5.plot(tvals, AMPKtot, 'k--', linewidth=2)
ax5.set_yscale('log')
ax5.set_ylabel('log species concentration')
ax5.set_xlabel('time (s)')
ax5.set_title('AMPK')
# Out:
# Text(0.5, 1.0, 'AMPK')
